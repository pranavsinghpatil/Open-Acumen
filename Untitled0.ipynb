# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import userdata

github_username = userdata.get('GITHUB_NAME')
github_pat = userdata.get('GITHUB_PAT')

# %% [markdown]
# First, retrieve your GitHub username and PAT from Colab's Secrets Manager. Make sure you named them appropriately in the Secrets Manager (e.g., `GITHUB_USERNAME` and `GITHUB_PAT`).

# %% [markdown]
# Next, configure Git to use these credentials. We'll use a temporary URL with the PAT embedded for authentication.

# %%
import os

repo_url = f"https://{github_username}:{github_pat}@github.com/pranavsinghpatil/Open-Acumen.git"
os.environ['GIT_ASKPASS'] = '' # Disable git-gui prompt if it appears
# !git remote set-url origin {repo_url}

# %%
# %cd /content/drive/MyDrive/stuffs/Open-Acumen/
# Out:
# /content/drive/MyDrive/stuffs/Open-Acumen

# %%
# !git clone https://github.com/pranavsinghpatil/Open-Acumen.git
# Out:
# Cloning into 'Open-Acumen'...
# remote: Enumerating objects: 2637, done.
# remote: Counting objects: 100% (2637/2637), done.
# remote: Compressing objects: 100% (2478/2478), done.
# remote: Total 2637 (delta 124), reused 2616 (delta 115), pack-reused 0 (from 0)
# Receiving objects: 100% (2637/2637), 20.48 MiB | 9.80 MiB/s, done.
# Resolving deltas: 100% (124/124), done.
# Updating files: 100% (233/233), done.

# %%
# %cd Open-Acumen
# Out:
# /content/drive/MyDrive/stuffs/Open-Acumen

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Untitled0.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add . # Adds all new and modified files
# Or !git add your_notebook_name.ipynb

# %%
# !git commit -m "colab-integration"
# Out:
# [main ef2e6ea] colab-integration
#  1 file changed, 1 insertion(+)
#  create mode 100644 Untitled0.ipynb

# %%
# You'll need to provide your GitHub username and Personal Access Token (PAT)
# Never hardcode your PAT directly in the notebook!
# Use colab's secrets manager, or input when prompted.
# For simplicity, during testing, you might be prompted to enter.
# !git push origin main # or master, depending on your branch name
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# Now you can push your changes to GitHub.

# %%
# !git push origin main # or master, depending on your branch name
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.56 KiB | 227.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/pranavsinghpatil/Open-Acumen.git
#    6f44760..ef2e6ea  main -> main
